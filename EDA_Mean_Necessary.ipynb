# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chroma= pd.read_csv('E://Dataval//Voice//chroma_stft_data.csv')

# %%
chroma.arr_1.min()
# Out:
# 0.01075063089698051

# %%
chroma.arr_1.max()
# Out:
# 1.0

# %%
len(chroma.arr_1.unique())
# Out:
# 1286

# %%
chroma.arr_1.mean()
# Out:
# 0.28812570635621615

# %%
chroma.arr_1.median()
# Out:
# 0.2992598374253209

# %%
chroma.arr_1.mode()
# Out:
# 0    1.0
# dtype: float64

# %%
len(chroma[chroma.arr_1==1.0])
# Out:
# 7

# %%
len(chroma.arr_1)
# Out:
# 1292

# %%
np.percentile(chroma.arr_1,.25)
# Out:
# 0.012945201648560821

# %%
np.percentile(chroma.arr_1,.5)
# Out:
# 0.015208252342053028

# %%
np.percentile(chroma.arr_1,.75)
# Out:
# 0.016926362237139427

# %%
np.percentile(chroma.arr_1,1)
# Out:
# 0.020899734162784265

# %%
import math

# %%
p5 = st.percentileofscore(chroma.arr_1, 0.28812570635621615)

# %%
p5
# Out:
# 46.20743034055727

# %%
p6 = st.percentileofscore(chroma.arr_1, 0.2992598374253209)

# %%
p6
# Out:
# 50.0

# %%
import scipy
import scipy.stats as st

st.percentileofscore
# Out:
# <function scipy.stats.stats.percentileofscore(a, score, kind='rank')>

# %%
print(chroma.arr_1.min())
print(chroma.arr_1.max())
print(chroma.arr_1.mean())
print(chroma.arr_1.median())
print(chroma.arr_1.mode())
print(st.percentileofscore(chroma.arr_1, 0.28812570635621615))
# Out:
# 0.01075063089698051
# 1.0
# 0.28812570635621615
# 0.2992598374253209
# 0    1.0
# dtype: float64
# 46.20743034055727

# %%
print(chroma.arr_2.min())
print(chroma.arr_2.max())
print(chroma.arr_2.mean())
print(chroma.arr_2.median())
print(chroma.arr_2.mode())
print(st.percentileofscore(chroma.arr_2, 0.7000514098323064))
# Out:
# 0.03412806573200275
# 1.0
# 0.7000514098323064
# 0.9128141162193792
# 0    1.0
# dtype: float64
# 42.80185758513932

# %%
print(chroma.arr_3.min())
print(chroma.arr_3.max())
print(chroma.arr_3.mean())
print(chroma.arr_3.median())
#print(chroma.arr_3.mode())
print(st.percentileofscore(chroma.arr_3, 0.3240071767014013))
# Out:
# 0.014627589355935316
# 0.9467625094886926
# 0.3240071767014013
# 0.3737378606621362
# 43.4984520123839

# %%
print(chroma.arr_4.min())
print(chroma.arr_4.max())
print(chroma.arr_4.mean())
print(chroma.arr_4.median())
#print(chroma.arr_3.mode())
print(st.percentileofscore(chroma.arr_4, 0.21523469379355387))
# Out:
# 0.005168594077782185
# 1.0
# 0.21523469379355387
# 0.0846003633311489
# 75.38699690402477

# %%
print(chroma.arr_5.min())
print(chroma.arr_5.max())
print(chroma.arr_5.mean())
print(chroma.arr_5.median())
#print(chroma.arr_3.mode())
print(st.percentileofscore(chroma.arr_5, 0.2452500891717776))
# Out:
# 0.002270468034260089
# 1.0
# 0.2452500891717776
# 0.1093855802834709
# 72.9876160990712

# %%
print(chroma.arr_6.min())
print(chroma.arr_6.max())
print(chroma.arr_6.mean())
print(chroma.arr_6.median())
#print(chroma.arr_3.mode())
print(st.percentileofscore(chroma.arr_6, 0.2452500891717776))
# Out:
# 0.011595865099148246
# 1.0
# 0.36397327160716497
# 0.28299625910028375
# 45.89783281733746

# %%
print(chroma.arr_7.min())
print(chroma.arr_7.max())
print(chroma.arr_7.mean())
print(chroma.arr_7.median())
#print(chroma.arr_3.mode())
print(st.percentileofscore(chroma.arr_7, 0.3500679021346842))
# Out:
# 0.004544045260329271
# 1.0
# 0.3500679021346842
# 0.23789879614658638
# 61.22291021671827

# %%
print(chroma.arr_8.min())
print(chroma.arr_8.max())
print(chroma.arr_8.mean())
print(chroma.arr_8.median())
#print(chroma.arr_3.mode())
print(st.percentileofscore(chroma.arr_8, chroma.arr_8.mean()))
# Out:
# 0.0029291837969072664
# 0.9863086786390696
# 0.1574267771562957
# 0.09554001328350997
# 66.0216718266254

# %%
print(chroma.arr_9.min())
print(chroma.arr_9.max())
print(chroma.arr_9.mean())
print(chroma.arr_9.median())
#print(chroma.arr_3.mode())
print(st.percentileofscore(chroma.arr_9, chroma.arr_9.mean()))
# Out:
# 0.007382292253264214
# 1.0
# 0.27246693863978255
# 0.19052580531037744
# 67.6470588235294

# %%
chroma.columns
# Out:
# Index(['arr_1', 'arr_2', 'arr_3', 'arr_4', 'arr_5', 'arr_6', 'arr_7', 'arr_8',
#        'arr_9', 'arr_10', 'arr_11', 'arr_12', 'rmse', 'spec_cent', 'spec_bw',
#        'rolloff', 'zcr'],
#       dtype='object')

# %%
len(chroma.columns)
# Out:
# 17

# %%
for idx,val in enumerate(chroma.columns):
    print(idx)
    print(val)
# Out:
# 0
# arr_1
# 1
# arr_2
# 2
# arr_3
# 3
# arr_4
# 4
# arr_5
# 5
# arr_6
# 6
# arr_7
# 7
# arr_8
# 8
# arr_9
# 9
# arr_10
# 10
# arr_11
# 11
# arr_12
# 12
# rmse
# 13
# spec_cent
# 14
# spec_bw
# 15
# rolloff
# 16
# zcr

# %%
for i in chroma:
    print(chroma.get(i).min())
    print(chroma.get(i).max())
    print(chroma.get(i).mean())
    print(chroma.get(i).median())
    print(st.percentileofscore(chroma.get(i), chroma.get(i).mean()))
    print("*"*100)
# Out:
# 0.01075063089698051
# 1.0
# 0.28812570635621615
# 0.2992598374253209
# 46.20743034055727
# ****************************************************************************************************
# 0.03412806573200275
# 1.0
# 0.7000514098323064
# 0.9128141162193792
# 42.80185758513932
# ****************************************************************************************************
# 0.014627589355935316
# 0.9467625094886926
# 0.3240071767014013
# 0.3737378606621362
# 43.4984520123839
# ****************************************************************************************************
# 0.005168594077782185
# 1.0
# 0.21523469379355387
# 0.0846003633311489
# 75.38699690402477
# ****************************************************************************************************
# 0.002270468034260089
# 1.0
# 0.2452500891717776
# 0.1093855802834709
# 72.9876160990712
# ****************************************************************************************************
# ...

# %%
chroma= pd.read_csv('E://Dataval//Voice//chroma_stft_data_blues.csv')

# %%
for i in chroma:
    print(chroma.get(i).min())
    print(chroma.get(i).max())
    print(chroma.get(i).mean())
    print(chroma.get(i).median())
    print(st.percentileofscore(chroma.get(i), chroma.get(i).mean()))
    print("*"*100)
# Out:
# 0.0032597797673212755
# 1.0
# 0.3436391575465284
# 0.23818739696395205
# 61.919504643962846
# ****************************************************************************************************
# 0.002293270085043848
# 1.0
# 0.3148854748871847
# 0.2326780792725331
# 59.13312693498452
# ****************************************************************************************************
# 0.0029016163585816783
# 1.0
# 0.3162370259328946
# 0.2239110661764204
# 60.68111455108359
# ****************************************************************************************************
# 0.004547901431616997
# 1.0
# 0.3378644209680647
# 0.24447222172831912
# 59.907120743034056
# ****************************************************************************************************
# 0.0048402310252391905
# 1.0
# 0.4391758583483064
# 0.3495031016444318
# 56.656346749226
# ****************************************************************************************************
# 0.006495406838060625
# ...

# %%
chroma= pd.read_csv(r'E:\Dataval\Anil\data_genres//chroma_stft_data_country.csv')
for i in chroma:
    print("Minimum:",chroma.get(i).min())
    print("Maximum:",chroma.get(i).max())
    print("Mean:",chroma.get(i).mean())
    print("Median:",chroma.get(i).median())
    print("Percentile wrt mean value:",st.percentileofscore(chroma.get(i), chroma.get(i).mean()))
    print("*"*100)
# Out:
# Minimum: 0.00732516106512922
# Maximum: 1.0
# Mean: 0.2129062159745026
# Median: 0.14265148104650963
# Percentile wrt mean value: 66.17647058823529
# ****************************************************************************************************
# Minimum: 0.009195204537529342
# Maximum: 1.0
# Mean: 0.2947966977195162
# Median: 0.21234486406542866
# Percentile wrt mean value: 62.461300309597526
# ****************************************************************************************************
# Minimum: 0.010134498814254805
# Maximum: 1.0
# Mean: 0.31454388057495614
# Median: 0.20378081860480513
# Percentile wrt mean value: 64.70588235294117
# ****************************************************************************************************
# Minimum: 0.01669565915292915
# Maximum: 1.0
# Mean: 0.4007987204122977
# Median: 0.32357498599811163
# Percentile wrt mean value: 60.68111455108359
# ...

# %%
chroma= pd.read_csv(r'E:\Dataval\Anil\data_genres//chroma_stft_data_disco.csv')
for i in chroma:
    print("Minimum:",chroma.get(i).min())
    print("Maximum:",chroma.get(i).max())
    print("Mean:",chroma.get(i).mean())
    print("Median:",chroma.get(i).median())
    print("Percentile wrt mean value:",st.percentileofscore(chroma.get(i), chroma.get(i).mean()))
    #
    print("*"*100)
# Out:
# Minimum: 0.018617037408118032
# Maximum: 1.0
# Mean: 0.5551220740160829
# Median: 0.48978053716099057
# Percentile wrt mean value: 53.09597523219814
# ****************************************************************************************************
# Minimum: 0.008745648006017832
# Maximum: 1.0
# Mean: 0.5278973456325705
# Median: 0.5444816725499197
# Percentile wrt mean value: 47.98761609907121
# ****************************************************************************************************
# Minimum: 0.006717829693956043
# Maximum: 1.0
# Mean: 0.5070584858050416
# Median: 0.45899247586653186
# Percentile wrt mean value: 53.79256965944273
# ****************************************************************************************************
# Minimum: 0.005517300897835298
# Maximum: 1.0
# Mean: 0.4788443143462148
# Median: 0.4027590779417296
# Percentile wrt mean value: 53.94736842105263
# ...

# %%
chroma= pd.read_csv(r'E:\Dataval\Anil\data_genres//chroma_stft_data_country.csv')
for i in chroma:
    print("Minimum:",chroma.get(i).min())
    print("Maximum:",chroma.get(i).max())
    print("Mean:",chroma.get(i).mean())
    print("Median:",chroma.get(i).median())
    print("Percentile wrt mean value:",st.percentileofscore(chroma.get(i), chroma.get(i).mean()))
    #
    print("*"*100)
# Out:
# Minimum: 0.00732516106512922
# Maximum: 1.0
# Mean: 0.2129062159745026
# Median: 0.14265148104650963
# Percentile wrt mean value: 66.17647058823529
# ****************************************************************************************************
# Minimum: 0.009195204537529342
# Maximum: 1.0
# Mean: 0.2947966977195162
# Median: 0.21234486406542866
# Percentile wrt mean value: 62.461300309597526
# ****************************************************************************************************
# Minimum: 0.010134498814254805
# Maximum: 1.0
# Mean: 0.31454388057495614
# Median: 0.20378081860480513
# Percentile wrt mean value: 64.70588235294117
# ****************************************************************************************************
# Minimum: 0.01669565915292915
# Maximum: 1.0
# Mean: 0.4007987204122977
# Median: 0.32357498599811163
# Percentile wrt mean value: 60.68111455108359
# ...

# %%
chroma= pd.read_csv(r'E:\Dataval\Anil\data_genres//chroma_stft_data_hiphop.csv')
for i in chroma:
    print("Minimum:",chroma.get(i).min())
    print("Maximum:",chroma.get(i).max())
    print("Mean:",chroma.get(i).mean())
    print("Median:",chroma.get(i).median())
    print("Percentile wrt mean value:",st.percentileofscore(chroma.get(i), chroma.get(i).mean()))
    #
    print("*"*100)
# Out:
# Minimum: 0.07550304382725284
# Maximum: 1.0
# Mean: 0.6903773288495929
# Median: 0.7173945559657129
# Percentile wrt mean value: 48.06501547987616
# ****************************************************************************************************
# Minimum: 0.09906456270751113
# Maximum: 1.0
# Mean: 0.6031742524526441
# Median: 0.5790442785668425
# Percentile wrt mean value: 52.94117647058823
# ****************************************************************************************************
# Minimum: 0.09789560521795627
# Maximum: 1.0
# Mean: 0.4927175403170262
# Median: 0.45299779476251645
# Percentile wrt mean value: 55.88235294117647
# ****************************************************************************************************
# Minimum: 0.07859360062832989
# Maximum: 1.0
# Mean: 0.4928273870455664
# Median: 0.4421425694236123
# Percentile wrt mean value: 57.5077399380805
# ...

# %%
chroma= pd.read_csv(r'E:\Dataval\Anil\data_genres//chroma_stft_data_rock.csv')
for i in chroma:
    print("Minimum:",chroma.get(i).min())
    print("Maximum:",chroma.get(i).max())
    print("Mean:",chroma.get(i).mean())
    print("Median:",chroma.get(i).median())
    print("Percentile wrt mean value:",st.percentileofscore(chroma.get(i), chroma.get(i).mean()))
    #
    print("*"*100)
# Out:
# Minimum: 0.0017481004598154956
# Maximum: 1.0
# Mean: 0.31863143176976066
# Median: 0.24594030582671284
# Percentile wrt mean value: 62.15170278637771
# ****************************************************************************************************
# Minimum: 0.0038891120245318185
# Maximum: 1.0
# Mean: 0.3513026185565116
# Median: 0.25911856373494524
# Percentile wrt mean value: 60.68111455108359
# ****************************************************************************************************
# Minimum: 0.0063950261025297475
# Maximum: 1.0
# Mean: 0.3571261408762345
# Median: 0.3148136976694865
# Percentile wrt mean value: 56.037151702786375
# ****************************************************************************************************
# Minimum: 0.007575605801984248
# Maximum: 1.0
# Mean: 0.4424969890806657
# Median: 0.3563613821735786
# Percentile wrt mean value: 58.746130030959755
# ...

# %%
chroma= pd.read_csv(r'E:\Dataval\Anil\data_genres//chroma_stft_data_blues.csv')
for i in chroma:
    print("Minimum:",chroma.get(i).min())
    print("Maximum:",chroma.get(i).max())
    print("Mean:",chroma.get(i).mean())
    print("Median:",chroma.get(i).median())
    print("Percentile wrt mean value:",st.percentileofscore(chroma.get(i), chroma.get(i).mean()))
    #
    print("*"*100)
# Out:
# Minimum: 0.0032597797673212755
# Maximum: 1.0
# Mean: 0.3436391575465284
# Median: 0.23818739696395205
# Percentile wrt mean value: 61.919504643962846
# ****************************************************************************************************
# Minimum: 0.002293270085043848
# Maximum: 1.0
# Mean: 0.3148854748871847
# Median: 0.2326780792725331
# Percentile wrt mean value: 59.13312693498452
# ****************************************************************************************************
# Minimum: 0.0029016163585816783
# Maximum: 1.0
# Mean: 0.3162370259328946
# Median: 0.2239110661764204
# Percentile wrt mean value: 60.68111455108359
# ****************************************************************************************************
# Minimum: 0.004547901431616997
# Maximum: 1.0
# Mean: 0.3378644209680647
# Median: 0.24447222172831912
# Percentile wrt mean value: 59.907120743034056
# ...

# %%
chroma.describe()
# Out:
#              arr_1        arr_2        arr_3        arr_4        arr_5  \
# count  1292.000000  1292.000000  1292.000000  1292.000000  1292.000000
# mean      0.343639     0.314885     0.316237     0.337864     0.439176
# std       0.296766     0.268569     0.281924     0.291768     0.350619
# min       0.003260     0.002293     0.002902     0.004548     0.004840
# 25%       0.104501     0.096003     0.093494     0.093478     0.111540
# 50%       0.238187     0.232678     0.223911     0.244472     0.349503
# 75%       0.533261     0.476945     0.469582     0.526996     0.759796
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#              arr_6        arr_7        arr_8        arr_9       arr_10  \
# count  1292.000000  1292.000000  1292.000000  1292.000000  1292.000000
# mean      0.422324     0.420176     0.388373     0.360674     0.382988
# std       0.313771     0.301781     0.311687     0.287211     0.334831
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X1 = scaler.fit_transform(np.array(chroma.iloc[:, :], dtype = float))

# %%
X1.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-9426535b89c0> in <module>
# ----> 1 X1.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
sc=StandardScaler()

# %%
chroma = sc.fit_transform(chroma)

# %%
chroma.spec_cent
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-572656d98f6c> in <module>
# ----> 1 chroma.spec_cent
#
# AttributeError: 'numpy.ndarray' object has no attribute 'spec_cent'

# %%
for i,val in enumerate(X1):
    print("Minimum:",X1[i].min())
    print("Maximum:",X1[i].max())
    print("Mean:",X1[i].mean())
    print("Standard Deviation:",X1[i].std())
#     print("Median:",X1[i])
    print("Percentile wrt mean value:",st.percentileofscore(X1[i], X1[i].mean()))
    #
    print("*"*100)
# Out:
# Minimum: -1.559876721948223
# Maximum: 1.841787978375402
# Mean: -0.18547027591071358
# Standard Deviation: 0.9717511672903774
# Percentile wrt mean value: 58.8235294117647
# ****************************************************************************************************
# Minimum: -1.4295709069006912
# Maximum: 1.841787978375402
# Mean: 0.10908484103682123
# Standard Deviation: 1.0209986520374763
# Percentile wrt mean value: 47.05882352941177
# ****************************************************************************************************
# Minimum: -1.3332579131699067
# Maximum: 1.8434691275706863
# Mean: -0.15211251131507986
# Standard Deviation: 0.8968746423992715
# Percentile wrt mean value: 52.94117647058823
# ****************************************************************************************************
# Minimum: -1.2709377407558697
# Maximum: 2.083835494214058
# Mean: -0.16423892713978214
# Standard Deviation: 0.7853305700439996
# ...

# %%
df=X1[0]

# %%
df.min()
# Out:
# -1.559876721948223

# %%
chroma.spec_cent.min()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-144-d2ba9793849f> in <module>
# ----> 1 chroma.spec_cent.min()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'spec_cent'
